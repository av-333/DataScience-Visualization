# %%
import plotly.express as px
import plotly.graph_objs as go
import numpy as np

# %%
#Histogram using Plotly. 
dist_a = np.random.normal(0.5, 2.0, size=10000)
dist_b = np.random.normal(-1.5, 4.0, size=10000)

# %%
go.Histogram?

# %%
fig2 = go.Figure()
#fig1.add_trace(go.Histogram(x=dist_a,name='Distribution A',marker_color='red',nbinsx=10,opacity=0.5))
fig2.add_trace(go.Histogram(y=dist_b,name='Distribution B',marker_color='green',nbinsx=10,opacity=0.5))
#fig1.update_layout(boxmode='overlay')
# Out:
# <div>                            <div id="1298105c-a25d-402c-89da-27d797e2f9a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1298105c-a25d-402c-89da-27d797e2f9a2")) {                    Plotly.newPlot(                        "1298105c-a25d-402c-89da-27d797e2f9a2",                        [{"marker":{"color":"green"},"name":"Distribution B","nbinsx":10,"opacity":0.5,"y":[-0.4917101829185184,-3.7907210266847366,-3.404794216735113,-3.6831484043653964,0.32194332335516185,-0.9291761309307239,-4.282874879237145,-5.882230751773605,-2.3117284555649142,-4.463834937355948,4.986314105038722,5.374393936045606,-1.8210338849804484,-3.8350167500261674,-0.7140793803962912,-4.941132906689488,-3.7075493983369614,-5.122328451908988,5.0534003698685765,2.8518806987110
# ...

# %%
px.histogram?

# %%
px.histogram(x=dist_a,nbins=30,marginal='violin')
# Out:
# <div>                            <div id="0feee675-3b2c-44b5-af44-5e28a5b446c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0feee675-3b2c-44b5-af44-5e28a5b446c0")) {                    Plotly.newPlot(                        "0feee675-3b2c-44b5-af44-5e28a5b446c0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.8490984345406922,4.632415904395183,-2.9411652696691437,0.2573371209381982,-2.1636319671210744,0.1697597258389072,1.4302911797923596,-4.221401820606129,2.551697212757477,-1.9456732270365524,0.31111227821214316,-2.108939492
# ...

# %%
px.data.tips?

# %%
# Getting the tips data. 
df = px.data.tips()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
f1 = go.Figure()
px.strip(df, x='tip', y='time',color='sex', facet_col='size',facet_row='smoker')
# Out:
# <div>                            <div id="79ed7a3f-9ebb-41d9-a1f6-4a5e02a4b30e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79ed7a3f-9ebb-41d9-a1f6-4a5e02a4b30e")) {                    Plotly.newPlot(                        "79ed7a3f-9ebb-41d9-a1f6-4a5e02a4b30e",                        [{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"sex=Female<br>smoker=No<br>size=2<br>tip=%{x}<br>time=%{y}<extra></extra>","legendgroup":"Female","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#636efa"},"name":"Female","offsetgroup":"Female","orientation":"h","pointpos":0,"showlegend":true,"x":[1.01,3.02,2.75,2.23,3.0,3.0,2.6,1.5,2.47,2.2,3.25,4.08,3.5,1.5,1.8,1.68,2.52,2.0,2.0,2.83,1.5,2
# ...

# %%
df_sat = df[df['day']=='Sat']
df_sat_m = df_sat[df_sat['sex']=='Male']
df_sat_f = df_sat[df_sat['sex']=='Female']
df_sat_f
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 29        19.65  3.00  Female     No  Sat  Dinner     2
# 32        15.06  3.00  Female     No  Sat  Dinner     2
# 33        20.69  2.45  Female     No  Sat  Dinner     4
# 37        16.93  3.07  Female     No  Sat  Dinner     3
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 66        16.45  2.47  Female     No  Sat  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 71        17.07  3.00  Female     No  Sat  Dinner     3
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 74        14.73  2.20  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 104       20.92  4.08  Female     No  Sat  Dinner     2
# ...

# %%
import numpy as np
np.mean(df_sat_m['total_bill'])
np.median(df_sat_m['total_bill'])
np.std(df_sat_m['total_bill'])
# Out:
# 9.752591240753478

# %%
fig = go.Figure()
fig.add_trace(go.Box(
    y = df_sat_m['total_bill'],
    name='Only Mean Male',
    marker_color='royalblue',
    boxmean='sd' # represent mean
))
#fig.add_trace(go.Box(
#    y = df_sat_m['total_bill'],
#    name='Mean & SD Male',
#    marker_color='royalblue',
#    boxmean='sd' # represent mean and standard deviation
#))
# Out:
# <div>                            <div id="79762582-07d2-4662-b1f0-19ca050568df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79762582-07d2-4662-b1f0-19ca050568df")) {                    Plotly.newPlot(                        "79762582-07d2-4662-b1f0-19ca050568df",                        [{"boxmean":"sd","marker":{"color":"royalblue"},"name":"Only Mean Male","y":[20.65,17.92,39.42,19.82,17.81,13.37,12.69,21.7,9.55,18.35,17.78,24.06,16.31,18.69,31.27,16.04,38.01,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,20.23,15.01,12.02,10.51,17.92,15.36,20.49,25.21,18.24,14.0,50.81,15.81,26.59,38.73,24.27,30.06,25.89,48.33,28.15,11.59,7.74,20.45,13.28,24.01,15.69,11.61,10.77,15.53,10.07,12.6,32.83,29.03,22.67,17.82],"type":"box"}],                        {"
# ...

# %%
f2 = px.box(df, x="day", y="total_bill", color="smoker")
f2.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
f2.show()
# Out:
# <div>                            <div id="1d0a5f21-2416-441b-b871-6cc00fed4c73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d0a5f21-2416-441b-b871-6cc00fed4c73")) {                    Plotly.newPlot(                        "1d0a5f21-2416-441b-b871-6cc00fed4c73",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa"},"name":"No","notched":false,"offsetgroup":"No","orientation":"v","showlegend":true,"x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat
# ...

# %%
f3 = go.Figure()
tr1 = go.Box(x=df['day'], y=df['total_bill'],boxpoints='all',boxmean=True)
f3.add_trace(tr1)
# Out:
# <div>                            <div id="70091ffb-7fd8-444f-9fd1-4ea94f8a50ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70091ffb-7fd8-444f-9fd1-4ea94f8a50ba")) {                    Plotly.newPlot(                        "70091ffb-7fd8-444f-9fd1-4ea94f8a50ba",                        [{"boxmean":true,"boxpoints":"all","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","S
# ...

# %%
f1 = go.Figure()
tr1 = go.Violin(y=df_sat_m['total_bill'],name='Male',pointpos=-1.6,points='all')
tr2 = go.Violin(y=df_sat_f['total_bill'],name='Female',pointpos=1.6,points='all')
f1.add_trace(tr1)
f1.add_trace(tr2)
f1.show()
# Out:
# <div>                            <div id="8bf5e2f3-be49-4821-8fb3-2652bceb9e83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bf5e2f3-be49-4821-8fb3-2652bceb9e83")) {                    Plotly.newPlot(                        "8bf5e2f3-be49-4821-8fb3-2652bceb9e83",                        [{"name":"Male","pointpos":-1.6,"points":"all","y":[20.65,17.92,39.42,19.82,17.81,13.37,12.69,21.7,9.55,18.35,17.78,24.06,16.31,18.69,31.27,16.04,38.01,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,20.23,15.01,12.02,10.51,17.92,15.36,20.49,25.21,18.24,14.0,50.81,15.81,26.59,38.73,24.27,30.06,25.89,48.33,28.15,11.59,7.74,20.45,13.28,24.01,15.69,11.61,10.77,15.53,10.07,12.6,32.83,29.03,22.67,17.82],"type":"violin"},{"name":"Female","pointpos":1.6,"points":"all","y
# ...
