# %% [markdown]
# # Time Series And Animation #
#
# Series of data points that are indexed in time order.
# The independent variable is the time.
#
# Some examples : Stock Market Data, ECG, Weather Data, COVID Data...

# %%
#Load plotly 
import plotly.express as px
import plotly.graph_objs as go
import numpy as np
import datetime
import pandas as pd

# %%
df = px.data.stocks()
df
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
px.line(df, x='date', y='NFLX')
# Out:
# <div>                            <div id="22e09d97-ed72-4189-b97b-bbeb394cd544" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22e09d97-ed72-4189-b97b-bbeb394cd544")) {                    Plotly.newPlot(                        "22e09d97-ed72-4189-b97b-bbeb394cd544",                        [{"hovertemplate":"date=%{x}<br>NFLX=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05
# ...

# %%
f2 = go.Figure()
f2.add_trace(go.Scatter(x=df['date'], y=df['NFLX'],mode='lines'))
f2.show()
# Out:
# <div>                            <div id="f85c0cb1-99ed-4568-97a3-ae6c111ddcad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f85c0cb1-99ed-4568-97a3-ae6c111ddcad")) {                    Plotly.newPlot(                        "f85c0cb1-99ed-4568-97a3-ae6c111ddcad",                        [{"mode":"lines","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","2018-08-20","201
# ...

# %%
f2.update_xaxes(range=['2019-01-01', '2019-04-01'])
# Out:
# <div>                            <div id="97d94ff0-4518-4cc9-9069-41b0d5b79f20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97d94ff0-4518-4cc9-9069-41b0d5b79f20")) {                    Plotly.newPlot(                        "97d94ff0-4518-4cc9-9069-41b0d5b79f20",                        [{"mode":"lines","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","2018-08-20","201
# ...

# %%
f2 = go.Figure()
f2.add_trace(go.Scatter(x=df['date'], y=df['NFLX'],mode='lines'))
f2.update_xaxes(rangeslider_visible=True)
# Out:
# <div>                            <div id="42e05039-3892-467b-b207-e96ab3b489f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42e05039-3892-467b-b207-e96ab3b489f7")) {                    Plotly.newPlot(                        "42e05039-3892-467b-b207-e96ab3b489f7",                        [{"mode":"lines","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","2018-08-20","201
# ...

# %%
f3 = go.Figure()
f3.add_trace(go.Scatter(x=df['date'], y=df['GOOG'],mode='lines',name='GOOG'))
f3.update_xaxes(rangeslider_visible=True)
f3.update_xaxes(rangeselector=dict(
        buttons=list([
            dict(count=5, label="5D", step="day", stepmode="backward"),
            dict(count=1, label="1M", step="month", stepmode="backward"),
            dict(count=3, label="3M", step="month", stepmode="todate"),
            dict(count=6, label="6M", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1Y", step="year", stepmode="backward"),
            dict(label="MAX", step="all")
        ])))
# Out:
# <div>                            <div id="71bc08e6-b329-4412-9c11-7c336e0d35e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71bc08e6-b329-4412-9c11-7c336e0d35e9")) {                    Plotly.newPlot(                        "71bc08e6-b329-4412-9c11-7c336e0d35e9",                        [{"mode":"lines","name":"GOOG","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","20
# ...

# %%
f3 = go.Figure()
f3.add_trace(go.Scatter(x=df['date'], y=df['GOOG'],mode='lines',name='GOOG'))
f3.update_xaxes(rangeslider_visible=True)
f3.update_layout(hovermode='x unified', template='simple_white')
f3.update_traces(fill='tonexty',line_color='blue')
# Out:
# <div>                            <div id="742799c7-6c71-48ae-bb9e-890fbc00abfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("742799c7-6c71-48ae-bb9e-890fbc00abfc")) {                    Plotly.newPlot(                        "742799c7-6c71-48ae-bb9e-890fbc00abfc",                        [{"mode":"lines","name":"GOOG","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","20
# ...

# %%
df = pd.read_csv('apple_stocks.csv')
df
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['AAPL.Open'],
                high=df['AAPL.High'],
                low=df['AAPL.Low'],
                close=df['AAPL.Close'])])

fig.show()
# Out:
# <div>                            <div id="e14f82a3-835b-4a85-9267-4bb19951271b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e14f82a3-835b-4a85-9267-4bb19951271b")) {                    Plotly.newPlot(                        "e14f82a3-835b-4a85-9267-4bb19951271b",                        [{"close":[127.830002,128.720001,128.449997,129.5,133.0,132.169998,128.789993,130.419998,128.460007,129.089996,129.360001,128.539993,126.410004,126.599998,127.139999,124.510002,122.239998,124.449997,123.589996,124.949997,127.040001,128.470001,127.5,125.900002,127.209999,126.690002,123.379997,124.239998,123.25,126.370003,124.43,124.25,125.32,127.349998,126.010002,125.599998,126.559998,127.099998,126.849998,126.300003,126.779999,126.169998,124.75,127.599998,126.9100
# ...
